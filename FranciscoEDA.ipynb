# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv("FranciscoSalary.csv")
df.head() #Checking first 5 entries
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         EmployeeName                                        JobTitle BasePay  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)  155966
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)  212739
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC   77916
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134402
#
#   OvertimePay OtherPay      Benefits   TotalPay  TotalPayBenefits  Year
# 0           0   400184  Not Provided  567595.43         567595.43  2011
# 1      245132   137811  Not Provided  538909.28         538909.28  2011
# ...

# %%
df.tail() #Checking last 5 entries
# Out:
#               EmployeeName                JobTitle BasePay OvertimePay  \
# 312877     Daniel W Plautz  Public Service Trainee       0           0
# 312878    David J Thompson          Deputy Sheriff       0           0
# 312879  Keiko Weng Yee Lau  Public Service Trainee       0           0
# 312880          David Wong          Deputy Sheriff       0           0
# 312881     Debora E Howard       Recreation Leader       0           0
#
#        OtherPay Benefits  TotalPay  TotalPayBenefits  Year
# 312877        0        0       0.0               0.0  2018
# 312878        0        0       0.0               0.0  2018
# 312879        0        0       0.0               0.0  2018
# 312880        0        0       0.0               0.0  2018
# 312881        0        0       0.0               0.0  2018

# %%
df.describe() #Overall statistics of the database
# Out:
#             TotalPay  TotalPayBenefits           Year
# count  312882.000000     312882.000000  312882.000000
# mean    78802.645788     100928.339777    2014.625303
# std     53230.758542      66485.186495       2.290899
# min      -618.130000      -3628.780000    2011.000000
# 25%     38803.000000      48955.072500    2013.000000
# 50%     74908.790000     100011.290000    2015.000000
# 75%    111386.897500     142376.300000    2017.000000
# max    592394.340000     712802.360000    2018.000000

# %%
df["Year"].unique() #Checking if we truly have the years between 2011 and 2018
# Out:
# array([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], dtype=int64)

# %%
df.isnull().sum() #Finding out NaN values for each column
# Out:
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# dtype: int64

# %%
for f in df.columns:
    print(f,df[f].nunique()) #Checking the number of unique instances of an attribute
# Out:
# EmployeeName 130283
# JobTitle 2286
# BasePay 238165
# OvertimePay 141441
# OtherPay 167391
# Benefits 242085
# TotalPay 291072
# TotalPayBenefits 299391
# Year 8

# %%
df.isin([0]).any() #Checking if they the 0 value in them
# Out:
# EmployeeName        False
# JobTitle            False
# BasePay              True
# OvertimePay          True
# OtherPay             True
# Benefits             True
# TotalPay             True
# TotalPayBenefits     True
# Year                False
# dtype: bool

# %%
df.isin([0]).sum() #Seeing the amount of Zeros in each column
# Out:
# EmployeeName             0
# JobTitle                 0
# BasePay               2297
# OvertimePay         128313
# OtherPay             73788
# Benefits              2966
# TotalPay               704
# TotalPayBenefits        57
# Year                     0
# dtype: int64

# %%
df.groupby('Year').nunique()['JobTitle'] #Seeing how many unique jobs there is for each year
# Out:
# Year
# 2011    1045
# 2012    1044
# 2013    1051
# 2014     996
# 2015    1010
# 2016    1009
# 2017    1017
# 2018    1000
# Name: JobTitle, dtype: int64

# %%
df.groupby('Year').nunique()['EmployeeName'] #Seeing how many unique names there is for each year
# Out:
# Year
# 2011    33878
# 2012    34349
# 2013    36150
# 2014    36683
# 2015    37929
# 2016    39442
# 2017    40051
# 2018    40775
# Name: EmployeeName, dtype: int64

# %%
df['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator    17995
# Special Nurse       10857
# Registered Nurse     9249
# Firefighter          5891
# Custodian            5759
# Name: JobTitle, dtype: int64

# %%
series_list = ['BasePay', 'OvertimePay', 'OtherPay', 'Benefits']
for series in series_list:
    df[series] = pd.to_numeric(df[series], errors='coerce')  #Turning Objects types to float64 types for analyzing.

# %%
df[df['BasePay']<0] #Checking for negative BasePay values
# Out:
#                     EmployeeName                 JobTitle  BasePay  \
# 72832             Irwin Sidharta             Junior Clerk  -166.01
# 72865               Robert Scott             Junior Clerk  -121.63
# 72872            Chung Huey Kung             Junior Clerk  -109.22
# 72874                  Jordan Li             Junior Clerk  -106.60
# 72878            Richard Jackson             Junior Clerk  -101.88
# 72884     DiMarco McGhee-Stewart             Junior Clerk   -93.14
# 72888         Leopoldo Marasigan             Junior Clerk   -87.38
# 72894             Douglas Avalos             Junior Clerk   -75.67
# 72908            Norma Rodriguez             Junior Clerk   -59.59
# 72920           Charles Williams             Junior Clerk   -30.58
# 72922                John Draper                    Clerk    -9.50
# 188036                Lubna Kaur  PS Aide Health Services  -292.40
# 270571  Carlos R Castro Santiago                Custodian  -474.40
#
# ...

# %%
df[df['OvertimePay']<0] #Negative OvertimePay
# Out:
#              EmployeeName                   JobTitle    BasePay  OvertimePay  \
# 90714   Claudia M Sanchez  Senior Eligibility Worker   75033.03        -0.01
# 189090   Christine Martin  Clinical Nurse Specialist  196388.71        -0.01
# 264075    Xiao Ping Zhang                     Porter   21792.19      -292.80
#
#         OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# 90714    1540.00  28864.64   76573.02         105437.66  2013
# 189090    250.00  49279.20  196638.70         245917.90  2016
# 264075     94.68    215.96   21594.07          21810.03  2017

# %%
df[df['OtherPay']<0] #Negative OtherPay
# Out:
#                     EmployeeName                       JobTitle    BasePay  \
# 84969                  Pei  Meng  IS Business Analyst-Principal  101274.51
# 93200               Jose A Lemus           Custodial Supervisor   66744.00
# 96168           John G Alexander                       Gardener   59733.32
# 107184          Amelie E Bullard                  Special Nurse    6932.50
# 148649                 Joe Lopez     Counselor, Log Cabin Ranch       0.00
# 229006              Elvira James                    Secretary 2       0.00
# 255728        Myraflor F Salcedo         Patient Care Assistant   50342.10
# 259052            Crecy D Hudson  Medical Evaluations Assistant   49878.11
# 270571  Carlos R Castro Santiago                      Custodian    -474.40
# 296115             Kirby H Vilar          Medical Records Clerk   70009.70
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year
# ...

# %%
df[df['Benefits']<0] #Negative Benefits
# Out:
#                     EmployeeName                        JobTitle    BasePay  \
# 110528          Timothy E Gibson                Police Officer 3        NaN
# 110529            Mark E Laherty                Police Officer 3        NaN
# 110530             David P Kucia                Police Officer 3        NaN
# 144099        Leticia Villacampa                     Secretary 2       0.00
# 188036                Lubna Kaur         PS Aide Health Services    -292.40
# 218308              Diane Alcala  Marriage, Family & Child Cnslr       0.00
# 221742               Mary Hobson       Architectural Associate 2       0.00
# 223494             Jose L Albano        Fire Protection Engineer       0.00
# 224293             Patricia Gray              Physical Therapist       0.00
# 225797                  Doug Lee                  Assoc Engineer       0.00
# 225926            Teresa M Tapia      Transportation Planner III       0.00
# ...

# %%
df[df['TotalPay']<0] #Negative TotalPay
# Out:
#                     EmployeeName                    JobTitle  BasePay  \
# 148649                 Joe Lopez  Counselor, Log Cabin Ranch      0.0
# 188036                Lubna Kaur     PS Aide Health Services   -292.4
# 229006              Elvira James                 Secretary 2      0.0
# 270571  Carlos R Castro Santiago                   Custodian   -474.4
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year
# 148649          0.0   -618.13      0.00   -618.13           -618.13  2014
# 188036          0.0      0.00     -2.92   -292.40           -295.32  2015
# 229006          0.0    -60.00      6.69    -60.00            -53.31  2016
# 270571          0.0    -23.72    -79.35   -498.12           -577.47  2017

# %%
df[df['TotalPayBenefits']<0] #Negative TotalPayBenefits
# Out:
#                     EmployeeName                       JobTitle  BasePay  \
# 110528          Timothy E Gibson               Police Officer 3      NaN
# 110529            Mark E Laherty               Police Officer 3      NaN
# 110530             David P Kucia               Police Officer 3      NaN
# 148649                 Joe Lopez     Counselor, Log Cabin Ranch      0.0
# 188036                Lubna Kaur        PS Aide Health Services   -292.4
# 229004             Rana Calonsag          Executive Secretary 3      0.0
# 229005             Bruce W Moore            IS Engineer-Journey      0.0
# 229006              Elvira James                    Secretary 2      0.0
# 270571  Carlos R Castro Santiago                      Custodian   -474.4
# 270572           Melinda R Valle  Medical Evaluations Assistant      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year
# 110528          0.0      0.00     -2.73      0.00             -2.73  2013
# ...
